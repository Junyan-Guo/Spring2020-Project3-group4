# %%
# !pip install pyreadr
# !pip install PyDrive

# %%
import numpy as np
import os
import pandas as pd
import time
import xgboost as xgb
import pyreadr
import scipy.io as scio
from collections import OrderedDict
from google.colab import auth
from oauth2client.client import GoogleCredentials 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from scipy.io import loadmat
from scipy.spatial.distance import cdist
from sklearn import datasets
from sklearn import metrics 
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,GridSearchCV 
from sklearn.metrics import accuracy_score,classification_report
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale
from time import time

# %% [markdown]
# # ADVANCED MODEL

# %% [markdown]
# # Instruction
# 1. Upload training data file in the google drive
# 2. Get shareable link of the data file
# 3. Get file ID (the file ID can be obstained from the link.)
# 4. replace the file ID in corresponding code. (Detailed instruction also come with the code throughout the file.)

# %% [markdown]
# ##Part 0: set up control and work directories, extract paths.

# %%
####Authenticate the google drive account
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV #Perforing grid search 
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

# %% [markdown]
# ## Part 1: Import Data

# %%
#####get the file shareable link = https://drive.google.com/open?id=1oliwM2-sH8CD_3q3yUbLF836U9A1-Lc0
#####The file ID is the letter after "id=".

# %%
#####please replace the id of your file
download = drive.CreateFile({'id': '1oliwM2-sH8CD_3q3yUbLF836U9A1-Lc0'}) 
download.GetContentFile('train_set.zip')
# !unzip train_set.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/train_set/points/._1901.mat
#   inflating: train_set/points/1929.mat
#   inflating: __MACOSX/train_set/points/._1929.mat
#   inflating: train_set/points/0389.mat
#   inflating: __MACOSX/train_set/points/._0389.mat
#   inflating: train_set/points/1097.mat
#   inflating: __MACOSX/train_set/points/._1097.mat
#   inflating: train_set/points/1083.mat
#   inflating: __MACOSX/train_set/points/._1083.mat
#   inflating: train_set/points/0410.mat
#   inflating: __MACOSX/train_set/points/._0410.mat
#   inflating: train_set/points/2207.mat
#   inflating: __MACOSX/train_set/points/._2207.mat
#   inflating: train_set/points/1068.mat
#   inflating: __MACOSX/train_set/points/._1068.mat
#   inflating: train_set/points/0376.mat
#   inflating: __MACOSX/train_set/points/._0376.mat
#   inflating: train_set/points/0362.mat
#   inflating: __MACOSX/train_set/points/._0362.mat
#   inflating: train_set/points/2213.mat
#   inflating: __MACOSX/train_set/points/._2213.mat
#   inflating: train_set/points/0404.mat
#   inflating: __MACOSX/train_set/points/._0404.mat
#   inflating: train_set/points/1732.mat
#   inflating: __MACOSX/train_set/points/._1732.mat
#   inflating: train_set/points/1054.mat
#   inflating: __MACOSX/train_set/points/._1054.mat
#   inflating: train_set/points/1040.mat
#   inflating: __MACOSX/train_set/points/._1040.mat
#   inflating: train_set/points/0438.mat
#   inflating: __MACOSX/train_set/points/._0438.mat
#   inflating: train_set/points/1726.mat
#   inflating: __MACOSX/train_set/points/._1726.mat
#   inflating: train_set/points/0809.mat
#   inflating: __MACOSX/train_set/points/._0809.mat
#   inflating: train_set/points/1295.mat
#   inflating: __MACOSX/train_set/points/._1295.mat
#   inflating: train_set/points/0835.mat
#   inflating: __MACOSX/train_set/points/._0835.mat
#   inflating: train_set/points/0821.mat
#   inflating: __MACOSX/train_set/points/._0821.mat
#   inflating: train_set/points/1281.mat
#   inflating: __MACOSX/train_set/points/._1281.mat
#   inflating: train_set/points/0174.mat
#   inflating: __MACOSX/train_set/points/._0174.mat
#   inflating: train_set/points/2005.mat
#   inflating: __MACOSX/train_set/points/._2005.mat
#   inflating: train_set/points/0612.mat
#   inflating: __MACOSX/train_set/points/._0612.mat
#   inflating: train_set/points/1518.mat
#   inflating: __MACOSX/train_set/points/._1518.mat
#   inflating: train_set/points/0606.mat
#   inflating: __MACOSX/train_set/points/._0606.mat
#   inflating: train_set/points/2011.mat
#   inflating: __MACOSX/train_set/points/._2011.mat
#   inflating: train_set/points/0160.mat
#   inflating: __MACOSX/train_set/points/._0160.mat
#   inflating: train_set/points/0148.mat
#   inflating: __MACOSX/train_set/points/._0148.mat
#   inflating: train_set/points/1256.mat
#   inflating: __MACOSX/train_set/points/._1256.mat
#   inflating: train_set/points/1530.mat
#   inflating: __MACOSX/train_set/points/._1530.mat
#   inflating: train_set/points/2039.mat
#   inflating: __MACOSX/train_set/points/._2039.mat
#   inflating: train_set/points/1524.mat
#   inflating: __MACOSX/train_set/points/._1524.mat
#   inflating: train_set/points/1242.mat
#   inflating: __MACOSX/train_set/points/._1242.mat
#   inflating: train_set/points/0969.mat
#   inflating: __MACOSX/train_set/points/._0969.mat
#   inflating: train_set/points/0941.mat
#   inflating: __MACOSX/train_set/points/._0941.mat
#   inflating: train_set/points/1487.mat
#   inflating: __MACOSX/train_set/points/._1487.mat
#   inflating: train_set/points/0799.mat
#   inflating: __MACOSX/train_set/points/._0799.mat
#   inflating: train_set/points/0955.mat
#   inflating: __MACOSX/train_set/points/._0955.mat
#   inflating: train_set/points/1493.mat
#   inflating: __MACOSX/train_set/points/._1493.mat
#   inflating: train_set/points/2171.mat
#   inflating: __MACOSX/train_set/points/._2171.mat
#   inflating: train_set/points/0766.mat
#   inflating: __MACOSX/train_set/points/._0766.mat
#   inflating: train_set/points/1478.mat
#   inflating: __MACOSX/train_set/points/._1478.mat
#   inflating: train_set/points/0772.mat
#   inflating: __MACOSX/train_set/points/._0772.mat
#   inflating: train_set/points/2165.mat
#   inflating: __MACOSX/train_set/points/._2165.mat
#   inflating: train_set/points/0014.mat
#   inflating: __MACOSX/train_set/points/._0014.mat
#   inflating: train_set/points/1322.mat
#   inflating: __MACOSX/train_set/points/._1322.mat
#   inflating: train_set/points/0982.mat
#   inflating: __MACOSX/train_set/points/._0982.mat
#   inflating: train_set/points/1444.mat
#   inflating: __MACOSX/train_set/points/._1444.mat
#   inflating: train_set/points/2159.mat
#   inflating: __MACOSX/train_set/points/._2159.mat
#   inflating: train_set/points/0996.mat
#   inflating: __MACOSX/train_set/points/._0996.mat
#   inflating: train_set/points/1450.mat
#   inflating: __MACOSX/train_set/points/._1450.mat
#   inflating: train_set/points/1336.mat
#   inflating: __MACOSX/train_set/points/._1336.mat
#   inflating: train_set/points/0028.mat
#   inflating: __MACOSX/train_set/points/._0028.mat
#   inflating: train_set/points/1861.mat
#   inflating: __MACOSX/train_set/points/._1861.mat
#   inflating: train_set/points/1875.mat
#   inflating: __MACOSX/train_set/points/._1875.mat
#   inflating: train_set/points/1685.mat
#   inflating: __MACOSX/train_set/points/._1685.mat
#   inflating: train_set/points/2398.mat
#   inflating: __MACOSX/train_set/points/._2398.mat
#   inflating: train_set/points/1849.mat
#   inflating: __MACOSX/train_set/points/._1849.mat
#   inflating: train_set/points/1691.mat
#   inflating: __MACOSX/train_set/points/._1691.mat
#   inflating: train_set/points/0564.mat
#   inflating: __MACOSX/train_set/points/._0564.mat
#   inflating: train_set/points/2373.mat
#   inflating: __MACOSX/train_set/points/._2373.mat
#   inflating: train_set/points/2415.mat
#   inflating: __MACOSX/train_set/points/._2415.mat
#   inflating: train_set/points/0202.mat
#   inflating: __MACOSX/train_set/points/._0202.mat
#   inflating: train_set/points/0216.mat
#   inflating: __MACOSX/train_set/points/._0216.mat
#   inflating: train_set/points/1108.mat
#   inflating: __MACOSX/train_set/points/._1108.mat
#   inflating: train_set/points/2401.mat
#   inflating: __MACOSX/train_set/points/._2401.mat
#   inflating: train_set/points/2367.mat
#   inflating: __MACOSX/train_set/points/._2367.mat
#   inflating: train_set/points/0570.mat
#   inflating: __MACOSX/train_set/points/._0570.mat
#   inflating: train_set/points/1646.mat
#   inflating: __MACOSX/train_set/points/._1646.mat
#   inflating: train_set/points/0558.mat
#   inflating: __MACOSX/train_set/points/._0558.mat
#   inflating: train_set/points/1120.mat
#   inflating: __MACOSX/train_set/points/._1120.mat
#   inflating: train_set/points/2429.mat
#   inflating: __MACOSX/train_set/points/._2429.mat
#   inflating: train_set/points/1134.mat
#   inflating: __MACOSX/train_set/points/._1134.mat
#   inflating: train_set/points/1652.mat
#   inflating: __MACOSX/train_set/points/._1652.mat
#   inflating: train_set/points/1135.mat
#   inflating: __MACOSX/train_set/points/._1135.mat
#   inflating: train_set/points/1653.mat
#   inflating: __MACOSX/train_set/points/._1653.mat
#   inflating: train_set/points/0559.mat
#   inflating: __MACOSX/train_set/points/._0559.mat
#   inflating: train_set/points/1647.mat
#   inflating: __MACOSX/train_set/points/._1647.mat
#   inflating: train_set/points/2428.mat
#   inflating: __MACOSX/train_set/points/._2428.mat
#   inflating: train_set/points/1121.mat
#   inflating: __MACOSX/train_set/points/._1121.mat
#   inflating: train_set/points/2400.mat
#   inflating: __MACOSX/train_set/points/._2400.mat
#   inflating: train_set/points/1109.mat
#   inflating: __MACOSX/train_set/points/._1109.mat
#   inflating: train_set/points/0217.mat
#   inflating: __MACOSX/train_set/points/._0217.mat
#   inflating: train_set/points/0571.mat
#   inflating: __MACOSX/train_set/points/._0571.mat
#   inflating: train_set/points/2366.mat
#   inflating: __MACOSX/train_set/points/._2366.mat
#   inflating: train_set/points/2372.mat
#   inflating: __MACOSX/train_set/points/._2372.mat
#   inflating: train_set/points/0565.mat
#   inflating: __MACOSX/train_set/points/._0565.mat
#   inflating: train_set/points/0203.mat
#   inflating: __MACOSX/train_set/points/._0203.mat
#   inflating: train_set/points/2414.mat
#   inflating: __MACOSX/train_set/points/._2414.mat
#   inflating: train_set/points/1690.mat
#   inflating: __MACOSX/train_set/points/._1690.mat
#   inflating: train_set/points/1848.mat
#   inflating: __MACOSX/train_set/points/._1848.mat
#   inflating: train_set/points/2399.mat
#   inflating: __MACOSX/train_set/points/._2399.mat
#   inflating: train_set/points/1684.mat
#   inflating: __MACOSX/train_set/points/._1684.mat
#   inflating: train_set/points/1874.mat
#   inflating: __MACOSX/train_set/points/._1874.mat
#   inflating: train_set/points/1860.mat
#   inflating: __MACOSX/train_set/points/._1860.mat
#   inflating: train_set/points/1451.mat
#   inflating: __MACOSX/train_set/points/._1451.mat
#   inflating: train_set/points/0997.mat
#   inflating: __MACOSX/train_set/points/._0997.mat
#   inflating: train_set/points/2158.mat
#   inflating: __MACOSX/train_set/points/._2158.mat
#   inflating: train_set/points/0029.mat
#   inflating: __MACOSX/train_set/points/._0029.mat
#   inflating: train_set/points/1337.mat
#   inflating: __MACOSX/train_set/points/._1337.mat
#   inflating: train_set/points/1323.mat
#   inflating: __MACOSX/train_set/points/._1323.mat
#   inflating: train_set/points/1445.mat
#   inflating: __MACOSX/train_set/points/._1445.mat
#   inflating: train_set/points/0983.mat
#   inflating: __MACOSX/train_set/points/._0983.mat
#   inflating: train_set/points/2164.mat
#   inflating: __MACOSX/train_set/points/._2164.mat
#   inflating: train_set/points/0773.mat
#   inflating: __MACOSX/train_set/points/._0773.mat
#   inflating: train_set/points/0015.mat
#   inflating: __MACOSX/train_set/points/._0015.mat
#   inflating: train_set/points/0001.mat
#   inflating: __MACOSX/train_set/points/._0001.mat
#   inflating: train_set/points/1479.mat
#   inflating: __MACOSX/train_set/points/._1479.mat
#   inflating: train_set/points/0767.mat
#   inflating: __MACOSX/train_set/points/._0767.mat
#   inflating: train_set/points/2170.mat
#   inflating: __MACOSX/train_set/points/._2170.mat
#   inflating: train_set/points/1492.mat
#   inflating: __MACOSX/train_set/points/._1492.mat
#   inflating: train_set/points/0954.mat
#   inflating: __MACOSX/train_set/points/._0954.mat
#   inflating: train_set/points/0798.mat
#   inflating: __MACOSX/train_set/points/._0798.mat
#   inflating: train_set/points/1486.mat
#   inflating: __MACOSX/train_set/points/._1486.mat
#   inflating: train_set/points/0940.mat
#   inflating: __MACOSX/train_set/points/._0940.mat
#   inflating: train_set/points/0968.mat
#   inflating: __MACOSX/train_set/points/._0968.mat
#   inflating: train_set/points/1525.mat
#   inflating: __MACOSX/train_set/points/._1525.mat
#   inflating: train_set/points/1243.mat
#   inflating: __MACOSX/train_set/points/._1243.mat
#   inflating: train_set/points/1257.mat
#   inflating: __MACOSX/train_set/points/._1257.mat
#   inflating: train_set/points/0149.mat
#   inflating: __MACOSX/train_set/points/._0149.mat
#   inflating: train_set/points/2038.mat
#   inflating: __MACOSX/train_set/points/._2038.mat
#   inflating: train_set/points/1531.mat
#   inflating: __MACOSX/train_set/points/._1531.mat
#   inflating: train_set/points/2010.mat
#   inflating: __MACOSX/train_set/points/._2010.mat
#   inflating: train_set/points/0607.mat
#   inflating: __MACOSX/train_set/points/._0607.mat
#   inflating: train_set/points/1519.mat
#   inflating: __MACOSX/train_set/points/._1519.mat
#   inflating: train_set/points/0161.mat
#   inflating: __MACOSX/train_set/points/._0161.mat
#   inflating: train_set/points/0175.mat
#   inflating: __MACOSX/train_set/points/._0175.mat
#   inflating: train_set/points/0613.mat
#   inflating: __MACOSX/train_set/points/._0613.mat
#   inflating: train_set/points/2004.mat
#   inflating: __MACOSX/train_set/points/._2004.mat
#   inflating: train_set/points/0820.mat
#   inflating: __MACOSX/train_set/points/._0820.mat
#   inflating: train_set/points/1280.mat
#   inflating: __MACOSX/train_set/points/._1280.mat
#   inflating: train_set/points/1294.mat
#   inflating: __MACOSX/train_set/points/._1294.mat
#   inflating: train_set/points/0834.mat
#   inflating: __MACOSX/train_set/points/._0834.mat
#   inflating: train_set/points/0808.mat
#   inflating: __MACOSX/train_set/points/._0808.mat
#   inflating: train_set/points/1041.mat
#   inflating: __MACOSX/train_set/points/._1041.mat
#   inflating: train_set/points/1727.mat
#   inflating: __MACOSX/train_set/points/._1727.mat
#   inflating: train_set/points/0439.mat
#   inflating: __MACOSX/train_set/points/._0439.mat
#   inflating: train_set/points/1733.mat
#   inflating: __MACOSX/train_set/points/._1733.mat
#   inflating: train_set/points/1055.mat
#   inflating: __MACOSX/train_set/points/._1055.mat
#   inflating: train_set/points/0363.mat
#   inflating: __MACOSX/train_set/points/._0363.mat
#   inflating: train_set/points/0405.mat
#   inflating: __MACOSX/train_set/points/._0405.mat
#   inflating: train_set/points/2212.mat
#   inflating: __MACOSX/train_set/points/._2212.mat
#   inflating: train_set/points/2206.mat
#   inflating: __MACOSX/train_set/points/._2206.mat
#   inflating: train_set/points/0411.mat
#   inflating: __MACOSX/train_set/points/._0411.mat
#   inflating: train_set/points/0377.mat
#   inflating: __MACOSX/train_set/points/._0377.mat
#   inflating: train_set/points/1069.mat
#   inflating: __MACOSX/train_set/points/._1069.mat
#   inflating: train_set/points/1082.mat
#   inflating: __MACOSX/train_set/points/._1082.mat
#   inflating: train_set/points/1928.mat
#   inflating: __MACOSX/train_set/points/._1928.mat
#   inflating: train_set/points/1096.mat
#   inflating: __MACOSX/train_set/points/._1096.mat
#   inflating: train_set/points/0388.mat
#   inflating: __MACOSX/train_set/points/._0388.mat
#   inflating: train_set/points/1900.mat
#   inflating: __MACOSX/train_set/points/._1900.mat
#   inflating: train_set/points/1914.mat
#   inflating: __MACOSX/train_set/points/._1914.mat
#   inflating: train_set/points/1902.mat
#   inflating: __MACOSX/train_set/points/._1902.mat
#   inflating: train_set/points/1916.mat
#   inflating: __MACOSX/train_set/points/._1916.mat
#   inflating: train_set/points/1080.mat
#   inflating: __MACOSX/train_set/points/._1080.mat
#   inflating: train_set/points/1094.mat
#   inflating: __MACOSX/train_set/points/._1094.mat
#   inflating: train_set/points/2210.mat
#   inflating: __MACOSX/train_set/points/._2210.mat
#   inflating: train_set/points/0407.mat
#   inflating: __MACOSX/train_set/points/._0407.mat
#   inflating: train_set/points/1719.mat
#   inflating: __MACOSX/train_set/points/._1719.mat
#   inflating: train_set/points/0361.mat
#   inflating: __MACOSX/train_set/points/._0361.mat
#   inflating: train_set/points/0375.mat
#   inflating: __MACOSX/train_set/points/._0375.mat
#   inflating: train_set/points/0413.mat
#   inflating: __MACOSX/train_set/points/._0413.mat
#   inflating: train_set/points/2204.mat
#   inflating: __MACOSX/train_set/points/._2204.mat
#   inflating: train_set/points/1725.mat
#   inflating: __MACOSX/train_set/points/._1725.mat
#   inflating: train_set/points/1043.mat
#   inflating: __MACOSX/train_set/points/._1043.mat
#   inflating: train_set/points/1057.mat
#   inflating: __MACOSX/train_set/points/._1057.mat
#   inflating: train_set/points/0349.mat
#   inflating: __MACOSX/train_set/points/._0349.mat
#   inflating: train_set/points/2238.mat
#   inflating: __MACOSX/train_set/points/._2238.mat
#   inflating: train_set/points/1731.mat
#   inflating: __MACOSX/train_set/points/._1731.mat
#   inflating: train_set/points/1282.mat
#   inflating: __MACOSX/train_set/points/._1282.mat
#   inflating: train_set/points/0822.mat
#   inflating: __MACOSX/train_set/points/._0822.mat
#   inflating: train_set/points/0836.mat
#   inflating: __MACOSX/train_set/points/._0836.mat
#   inflating: train_set/points/1296.mat
#   inflating: __MACOSX/train_set/points/._1296.mat
#   inflating: train_set/points/0188.mat
#   inflating: __MACOSX/train_set/points/._0188.mat
#   inflating: train_set/points/0163.mat
#   inflating: __MACOSX/train_set/points/._0163.mat
#   inflating: train_set/points/0605.mat
#   inflating: __MACOSX/train_set/points/._0605.mat
#   inflating: train_set/points/2012.mat
#   inflating: __MACOSX/train_set/points/._2012.mat
#   inflating: train_set/points/2006.mat
#   inflating: __MACOSX/train_set/points/._2006.mat
#   inflating: train_set/points/0611.mat
#   inflating: __MACOSX/train_set/points/._0611.mat
#   inflating: train_set/points/0177.mat
#   inflating: __MACOSX/train_set/points/._0177.mat
#   inflating: train_set/points/1269.mat
#   inflating: __MACOSX/train_set/points/._1269.mat
#   inflating: train_set/points/1241.mat
#   inflating: __MACOSX/train_set/points/._1241.mat
#   inflating: train_set/points/1527.mat
#   inflating: __MACOSX/train_set/points/._1527.mat
#   inflating: train_set/points/0639.mat
#   inflating: __MACOSX/train_set/points/._0639.mat
#   inflating: train_set/points/1533.mat
#   inflating: __MACOSX/train_set/points/._1533.mat
#   inflating: train_set/points/1255.mat
#   inflating: __MACOSX/train_set/points/._1255.mat
#   inflating: train_set/points/0956.mat
#   inflating: __MACOSX/train_set/points/._0956.mat
#   inflating: train_set/points/1490.mat
#   inflating: __MACOSX/train_set/points/._1490.mat
#   inflating: train_set/points/2199.mat
#   inflating: __MACOSX/train_set/points/._2199.mat
#   inflating: train_set/points/0942.mat
#   inflating: __MACOSX/train_set/points/._0942.mat
#   inflating: train_set/points/1484.mat
#   inflating: __MACOSX/train_set/points/._1484.mat
#   inflating: train_set/points/1309.mat
#   inflating: __MACOSX/train_set/points/._1309.mat
#   inflating: train_set/points/0017.mat
#   inflating: __MACOSX/train_set/points/._0017.mat
#   inflating: train_set/points/0771.mat
#   inflating: __MACOSX/train_set/points/._0771.mat
#   inflating: train_set/points/2166.mat
#   inflating: __MACOSX/train_set/points/._2166.mat
#   inflating: train_set/points/2172.mat
#   inflating: __MACOSX/train_set/points/._2172.mat
#   inflating: train_set/points/0765.mat
#   inflating: __MACOSX/train_set/points/._0765.mat
#   inflating: train_set/points/0003.mat
#   inflating: __MACOSX/train_set/points/._0003.mat
#   inflating: train_set/points/1335.mat
#   inflating: __MACOSX/train_set/points/._1335.mat
#   inflating: train_set/points/0995.mat
#   inflating: __MACOSX/train_set/points/._0995.mat
#   inflating: train_set/points/1453.mat
#   inflating: __MACOSX/train_set/points/._1453.mat
#   inflating: train_set/points/0759.mat
#   inflating: __MACOSX/train_set/points/._0759.mat
#   inflating: train_set/points/0981.mat
#   inflating: __MACOSX/train_set/points/._0981.mat
#   inflating: train_set/points/1447.mat
#   inflating: __MACOSX/train_set/points/._1447.mat
#   inflating: train_set/points/1321.mat
#   inflating: __MACOSX/train_set/points/._1321.mat
#   inflating: train_set/points/1876.mat
#   inflating: __MACOSX/train_set/points/._1876.mat
#   inflating: train_set/points/1862.mat
#   inflating: __MACOSX/train_set/points/._1862.mat
#   inflating: train_set/points/1692.mat
#   inflating: __MACOSX/train_set/points/._1692.mat
#   inflating: train_set/points/0598.mat
#   inflating: __MACOSX/train_set/points/._0598.mat
#   inflating: train_set/points/1686.mat
#   inflating: __MACOSX/train_set/points/._1686.mat
#   inflating: train_set/points/2364.mat
#   inflating: __MACOSX/train_set/points/._2364.mat
#   inflating: train_set/points/0573.mat
#   inflating: __MACOSX/train_set/points/._0573.mat
#   inflating: train_set/points/0215.mat
#   inflating: __MACOSX/train_set/points/._0215.mat
#   inflating: train_set/points/2402.mat
#   inflating: __MACOSX/train_set/points/._2402.mat
#   inflating: train_set/points/2416.mat
#   inflating: __MACOSX/train_set/points/._2416.mat
#   inflating: train_set/points/0201.mat
#   inflating: __MACOSX/train_set/points/._0201.mat
#   inflating: train_set/points/1679.mat
#   inflating: __MACOSX/train_set/points/._1679.mat
#   inflating: train_set/points/0567.mat
#   inflating: __MACOSX/train_set/points/._0567.mat
#   inflating: train_set/points/2370.mat
#   inflating: __MACOSX/train_set/points/._2370.mat
#   inflating: train_set/points/1651.mat
#   inflating: __MACOSX/train_set/points/._1651.mat
#   inflating: train_set/points/1889.mat
#   inflating: __MACOSX/train_set/points/._1889.mat
#   inflating: train_set/points/2358.mat
#   inflating: __MACOSX/train_set/points/._2358.mat
#   inflating: train_set/points/0229.mat
#   inflating: __MACOSX/train_set/points/._0229.mat
#   inflating: train_set/points/1137.mat
#   inflating: __MACOSX/train_set/points/._1137.mat
#   inflating: train_set/points/1123.mat
#   inflating: __MACOSX/train_set/points/._1123.mat
#   inflating: train_set/points/1645.mat
#   inflating: __MACOSX/train_set/points/._1645.mat
#   inflating: train_set/points/1122.mat
#   inflating: __MACOSX/train_set/points/._1122.mat
#   inflating: train_set/points/1644.mat
#   inflating: __MACOSX/train_set/points/._1644.mat
#   inflating: train_set/points/2359.mat
#   inflating: __MACOSX/train_set/points/._2359.mat
#   inflating: train_set/points/1888.mat
#   inflating: __MACOSX/train_set/points/._1888.mat
#   inflating: train_set/points/1650.mat
#   inflating: __MACOSX/train_set/points/._1650.mat
#   inflating: train_set/points/1136.mat
#   inflating: __MACOSX/train_set/points/._1136.mat
#   inflating: train_set/points/0228.mat
#   inflating: __MACOSX/train_set/points/._0228.mat
#   inflating: train_set/points/0200.mat
#   inflating: __MACOSX/train_set/points/._0200.mat
#   inflating: train_set/points/2417.mat
#   inflating: __MACOSX/train_set/points/._2417.mat
#   inflating: train_set/points/2371.mat
#   inflating: __MACOSX/train_set/points/._2371.mat
#   inflating: train_set/points/0566.mat
#   inflating: __MACOSX/train_set/points/._0566.mat
#   inflating: train_set/points/1678.mat
#   inflating: __MACOSX/train_set/points/._1678.mat
#   inflating: train_set/points/0572.mat
#   inflating: __MACOSX/train_set/points/._0572.mat
#   inflating: train_set/points/2365.mat
#   inflating: __MACOSX/train_set/points/._2365.mat
#   inflating: train_set/points/2403.mat
#   inflating: __MACOSX/train_set/points/._2403.mat
#   inflating: train_set/points/0214.mat
#   inflating: __MACOSX/train_set/points/._0214.mat
#   inflating: train_set/points/1687.mat
#   inflating: __MACOSX/train_set/points/._1687.mat
#   inflating: train_set/points/0599.mat
#   inflating: __MACOSX/train_set/points/._0599.mat
#   inflating: train_set/points/1693.mat
#   inflating: __MACOSX/train_set/points/._1693.mat
#   inflating: train_set/points/1863.mat
#   inflating: __MACOSX/train_set/points/._1863.mat
#   inflating: train_set/points/1877.mat
#   inflating: __MACOSX/train_set/points/._1877.mat
#   inflating: train_set/points/1446.mat
#   inflating: __MACOSX/train_set/points/._1446.mat
#   inflating: train_set/points/0980.mat
#   inflating: __MACOSX/train_set/points/._0980.mat
#   inflating: train_set/points/0758.mat
#   inflating: __MACOSX/train_set/points/._0758.mat
#   inflating: train_set/points/1320.mat
#   inflating: __MACOSX/train_set/points/._1320.mat
#   inflating: train_set/points/1334.mat
#   inflating: __MACOSX/train_set/points/._1334.mat
#   inflating: train_set/points/1452.mat
#   inflating: __MACOSX/train_set/points/._1452.mat
#   inflating: train_set/points/0994.mat
#   inflating: __MACOSX/train_set/points/._0994.mat
#   inflating: train_set/points/0764.mat
#   inflating: __MACOSX/train_set/points/._0764.mat
#   inflating: train_set/points/2173.mat
#   inflating: __MACOSX/train_set/points/._2173.mat
#   inflating: train_set/points/0002.mat
#   inflating: __MACOSX/train_set/points/._0002.mat
#   inflating: train_set/points/0016.mat
#   inflating: __MACOSX/train_set/points/._0016.mat
#   inflating: train_set/points/1308.mat
#   inflating: __MACOSX/train_set/points/._1308.mat
#   inflating: train_set/points/2167.mat
#   inflating: __MACOSX/train_set/points/._2167.mat
#   inflating: train_set/points/0770.mat
#   inflating: __MACOSX/train_set/points/._0770.mat
#   inflating: train_set/points/1485.mat
#   inflating: __MACOSX/train_set/points/._1485.mat
#   inflating: train_set/points/0943.mat
#   inflating: __MACOSX/train_set/points/._0943.mat
#   inflating: train_set/points/2198.mat
#   inflating: __MACOSX/train_set/points/._2198.mat
#   inflating: train_set/points/1491.mat
#   inflating: __MACOSX/train_set/points/._1491.mat
#   inflating: train_set/points/0957.mat
#   inflating: __MACOSX/train_set/points/._0957.mat
#   inflating: train_set/points/1532.mat
#   inflating: __MACOSX/train_set/points/._1532.mat
#   inflating: train_set/points/1254.mat
#   inflating: __MACOSX/train_set/points/._1254.mat
#   inflating: train_set/points/1240.mat
#   inflating: __MACOSX/train_set/points/._1240.mat
#   inflating: train_set/points/0638.mat
#   inflating: __MACOSX/train_set/points/._0638.mat
#   inflating: train_set/points/1526.mat
#   inflating: __MACOSX/train_set/points/._1526.mat
#   inflating: train_set/points/0610.mat
#   inflating: __MACOSX/train_set/points/._0610.mat
#   inflating: train_set/points/2007.mat
#   inflating: __MACOSX/train_set/points/._2007.mat
#   inflating: train_set/points/1268.mat
#   inflating: __MACOSX/train_set/points/._1268.mat
#   inflating: train_set/points/0176.mat
#   inflating: __MACOSX/train_set/points/._0176.mat
#   inflating: train_set/points/0162.mat
#   inflating: __MACOSX/train_set/points/._0162.mat
#   inflating: train_set/points/2013.mat
#   inflating: __MACOSX/train_set/points/._2013.mat
#   inflating: train_set/points/0604.mat
#   inflating: __MACOSX/train_set/points/._0604.mat
#   inflating: train_set/points/0837.mat
#   inflating: __MACOSX/train_set/points/._0837.mat
#   inflating: train_set/points/0189.mat
#   inflating: __MACOSX/train_set/points/._0189.mat
#   inflating: train_set/points/1297.mat
#   inflating: __MACOSX/train_set/points/._1297.mat
#   inflating: train_set/points/1283.mat
#   inflating: __MACOSX/train_set/points/._1283.mat
#   inflating: train_set/points/0823.mat
#   inflating: __MACOSX/train_set/points/._0823.mat
#   inflating: train_set/points/0348.mat
#   inflating: __MACOSX/train_set/points/._0348.mat
#   inflating: train_set/points/1056.mat
#   inflating: __MACOSX/train_set/points/._1056.mat
#   inflating: train_set/points/1730.mat
#   inflating: __MACOSX/train_set/points/._1730.mat
#   inflating: train_set/points/2239.mat
#   inflating: __MACOSX/train_set/points/._2239.mat
#   inflating: train_set/points/1724.mat
#   inflating: __MACOSX/train_set/points/._1724.mat
#   inflating: train_set/points/1042.mat
#   inflating: __MACOSX/train_set/points/._1042.mat
#   inflating: train_set/points/0374.mat
#   inflating: __MACOSX/train_set/points/._0374.mat
#   inflating: train_set/points/2205.mat
#   inflating: __MACOSX/train_set/points/._2205.mat
#   inflating: train_set/points/0412.mat
#   inflating: __MACOSX/train_set/points/._0412.mat
#   inflating: train_set/points/1718.mat
#   inflating: __MACOSX/train_set/points/._1718.mat
#   inflating: train_set/points/0406.mat
#   inflating: __MACOSX/train_set/points/._0406.mat
#   inflating: train_set/points/2211.mat
#   inflating: __MACOSX/train_set/points/._2211.mat
#   inflating: train_set/points/0360.mat
#   inflating: __MACOSX/train_set/points/._0360.mat
#   inflating: train_set/points/1095.mat
#   inflating: __MACOSX/train_set/points/._1095.mat
#   inflating: train_set/points/1081.mat
#   inflating: __MACOSX/train_set/points/._1081.mat
#   inflating: train_set/points/1917.mat
#   inflating: __MACOSX/train_set/points/._1917.mat
#   inflating: train_set/points/1903.mat
#   inflating: __MACOSX/train_set/points/._1903.mat
#   inflating: train_set/points/1085.mat
#   inflating: __MACOSX/train_set/points/._1085.mat
#   inflating: train_set/points/1091.mat
#   inflating: __MACOSX/train_set/points/._1091.mat
#   inflating: train_set/points/1907.mat
#   inflating: __MACOSX/train_set/points/._1907.mat
#   inflating: train_set/points/1913.mat
#   inflating: __MACOSX/train_set/points/._1913.mat
#   inflating: train_set/points/1046.mat
#   inflating: __MACOSX/train_set/points/._1046.mat
#   inflating: train_set/points/0358.mat
#   inflating: __MACOSX/train_set/points/._0358.mat
#   inflating: train_set/points/1720.mat
#   inflating: __MACOSX/train_set/points/._1720.mat
#   inflating: train_set/points/2229.mat
#   inflating: __MACOSX/train_set/points/._2229.mat
#   inflating: train_set/points/1734.mat
#   inflating: __MACOSX/train_set/points/._1734.mat
#   inflating: train_set/points/1052.mat
#   inflating: __MACOSX/train_set/points/._1052.mat
#   inflating: train_set/points/0364.mat
#   inflating: __MACOSX/train_set/points/._0364.mat
#   inflating: train_set/points/2215.mat
#   inflating: __MACOSX/train_set/points/._2215.mat
#   inflating: train_set/points/0402.mat
#   inflating: __MACOSX/train_set/points/._0402.mat
#   inflating: train_set/points/0416.mat
#   inflating: __MACOSX/train_set/points/._0416.mat
#   inflating: train_set/points/1708.mat
#   inflating: __MACOSX/train_set/points/._1708.mat
#   inflating: train_set/points/2201.mat
#   inflating: __MACOSX/train_set/points/._2201.mat
#   inflating: train_set/points/0370.mat
#   inflating: __MACOSX/train_set/points/._0370.mat
#   inflating: train_set/points/0827.mat
#   inflating: __MACOSX/train_set/points/._0827.mat
#   inflating: train_set/points/1287.mat
#   inflating: __MACOSX/train_set/points/._1287.mat
#   inflating: train_set/points/0199.mat
#   inflating: __MACOSX/train_set/points/._0199.mat
#   inflating: train_set/points/1293.mat
#   inflating: __MACOSX/train_set/points/._1293.mat
#   inflating: train_set/points/0833.mat
#   inflating: __MACOSX/train_set/points/._0833.mat
#   inflating: train_set/points/1522.mat
#   inflating: __MACOSX/train_set/points/._1522.mat
#   inflating: train_set/points/1244.mat
#   inflating: __MACOSX/train_set/points/._1244.mat
#   inflating: train_set/points/1250.mat
#   inflating: __MACOSX/train_set/points/._1250.mat
#   inflating: train_set/points/1536.mat
#   inflating: __MACOSX/train_set/points/._1536.mat
#   inflating: train_set/points/0628.mat
#   inflating: __MACOSX/train_set/points/._0628.mat
#   inflating: train_set/points/0600.mat
#   inflating: __MACOSX/train_set/points/._0600.mat
#   inflating: train_set/points/2017.mat
#   inflating: __MACOSX/train_set/points/._2017.mat
#   inflating: train_set/points/0166.mat
#   inflating: __MACOSX/train_set/points/._0166.mat
#   inflating: train_set/points/1278.mat
#   inflating: __MACOSX/train_set/points/._1278.mat
#   inflating: train_set/points/0172.mat
#   inflating: __MACOSX/train_set/points/._0172.mat
#   inflating: train_set/points/2003.mat
#   inflating: __MACOSX/train_set/points/._2003.mat
#   inflating: train_set/points/0614.mat
#   inflating: __MACOSX/train_set/points/._0614.mat
#   inflating: train_set/points/1495.mat
#   inflating: __MACOSX/train_set/points/._1495.mat
#   inflating: train_set/points/0953.mat
#   inflating: __MACOSX/train_set/points/._0953.mat
#   inflating: train_set/points/2188.mat
#   inflating: __MACOSX/train_set/points/._2188.mat
#   inflating: train_set/points/1481.mat
#   inflating: __MACOSX/train_set/points/._1481.mat
#   inflating: train_set/points/0947.mat
#   inflating: __MACOSX/train_set/points/._0947.mat
#   inflating: train_set/points/0748.mat
#   inflating: __MACOSX/train_set/points/._0748.mat
#   inflating: train_set/points/1456.mat
#   inflating: __MACOSX/train_set/points/._1456.mat
#   inflating: train_set/points/0990.mat
#   inflating: __MACOSX/train_set/points/._0990.mat
#   inflating: train_set/points/1330.mat
#   inflating: __MACOSX/train_set/points/._1330.mat
#   inflating: train_set/points/1324.mat
#   inflating: __MACOSX/train_set/points/._1324.mat
#   inflating: train_set/points/1442.mat
#   inflating: __MACOSX/train_set/points/._1442.mat
#   inflating: train_set/points/0984.mat
#   inflating: __MACOSX/train_set/points/._0984.mat
#   inflating: train_set/points/0774.mat
#   inflating: __MACOSX/train_set/points/._0774.mat
#   inflating: train_set/points/2163.mat
#   inflating: __MACOSX/train_set/points/._2163.mat
#   inflating: train_set/points/0012.mat
#   inflating: __MACOSX/train_set/points/._0012.mat
#   inflating: train_set/points/1318.mat
#   inflating: __MACOSX/train_set/points/._1318.mat
#   inflating: train_set/points/0006.mat
#   inflating: __MACOSX/train_set/points/._0006.mat
#   inflating: train_set/points/2177.mat
#   inflating: __MACOSX/train_set/points/._2177.mat
#   inflating: train_set/points/0760.mat
#   inflating: __MACOSX/train_set/points/._0760.mat
#   inflating: train_set/points/0589.mat
#   inflating: __MACOSX/train_set/points/._0589.mat
#   inflating: train_set/points/1697.mat
#   inflating: __MACOSX/train_set/points/._1697.mat
#   inflating: train_set/points/1683.mat
#   inflating: __MACOSX/train_set/points/._1683.mat
#   inflating: train_set/points/1873.mat
#   inflating: __MACOSX/train_set/points/._1873.mat
#   inflating: train_set/points/1867.mat
#   inflating: __MACOSX/train_set/points/._1867.mat
#   inflating: train_set/points/1132.mat
#   inflating: __MACOSX/train_set/points/._1132.mat
#   inflating: train_set/points/1654.mat
#   inflating: __MACOSX/train_set/points/._1654.mat
#   inflating: train_set/points/2349.mat
#   inflating: __MACOSX/train_set/points/._2349.mat
#   inflating: train_set/points/1640.mat
#   inflating: __MACOSX/train_set/points/._1640.mat
#   inflating: train_set/points/1898.mat
#   inflating: __MACOSX/train_set/points/._1898.mat
#   inflating: train_set/points/0238.mat
#   inflating: __MACOSX/train_set/points/._0238.mat
#   inflating: train_set/points/1126.mat
#   inflating: __MACOSX/train_set/points/._1126.mat
#   inflating: train_set/points/0210.mat
#   inflating: __MACOSX/train_set/points/._0210.mat
#   inflating: train_set/points/2407.mat
#   inflating: __MACOSX/train_set/points/._2407.mat
#   inflating: train_set/points/2361.mat
#   inflating: __MACOSX/train_set/points/._2361.mat
#   inflating: train_set/points/1668.mat
#   inflating: __MACOSX/train_set/points/._1668.mat
#   inflating: train_set/points/0576.mat
#   inflating: __MACOSX/train_set/points/._0576.mat
#   inflating: train_set/points/0562.mat
#   inflating: __MACOSX/train_set/points/._0562.mat
#   inflating: train_set/points/2375.mat
#   inflating: __MACOSX/train_set/points/._2375.mat
#   inflating: train_set/points/2413.mat
#   inflating: __MACOSX/train_set/points/._2413.mat
#   inflating: train_set/points/0204.mat
#   inflating: __MACOSX/train_set/points/._0204.mat
#   inflating: train_set/points/2374.mat
#   inflating: __MACOSX/train_set/points/._2374.mat
#   inflating: train_set/points/0563.mat
#   inflating: __MACOSX/train_set/points/._0563.mat
#   inflating: train_set/points/0205.mat
#   inflating: __MACOSX/train_set/points/._0205.mat
#   inflating: train_set/points/2412.mat
#   inflating: __MACOSX/train_set/points/._2412.mat
#   inflating: train_set/points/2406.mat
#   inflating: __MACOSX/train_set/points/._2406.mat
#   inflating: train_set/points/0211.mat
#   inflating: __MACOSX/train_set/points/._0211.mat
#   inflating: train_set/points/0577.mat
#   inflating: __MACOSX/train_set/points/._0577.mat
#   inflating: train_set/points/1669.mat
#   inflating: __MACOSX/train_set/points/._1669.mat
#   inflating: train_set/points/2360.mat
#   inflating: __MACOSX/train_set/points/._2360.mat
#   inflating: train_set/points/1899.mat
#   inflating: __MACOSX/train_set/points/._1899.mat
#   inflating: train_set/points/1641.mat
#   inflating: __MACOSX/train_set/points/._1641.mat
#   inflating: train_set/points/2348.mat
#   inflating: __MACOSX/train_set/points/._2348.mat
#   inflating: train_set/points/1127.mat
#   inflating: __MACOSX/train_set/points/._1127.mat
#   inflating: train_set/points/0239.mat
#   inflating: __MACOSX/train_set/points/._0239.mat
#   inflating: train_set/points/1133.mat
#   inflating: __MACOSX/train_set/points/._1133.mat
#   inflating: train_set/points/1655.mat
#   inflating: __MACOSX/train_set/points/._1655.mat
#   inflating: train_set/points/1866.mat
#   inflating: __MACOSX/train_set/points/._1866.mat
#   inflating: train_set/points/1872.mat
#   inflating: __MACOSX/train_set/points/._1872.mat
#   inflating: train_set/points/1682.mat
#   inflating: __MACOSX/train_set/points/._1682.mat
#   inflating: train_set/points/1696.mat
#   inflating: __MACOSX/train_set/points/._1696.mat
#   inflating: train_set/points/0588.mat
#   inflating: __MACOSX/train_set/points/._0588.mat
#   inflating: train_set/points/0007.mat
#   inflating: __MACOSX/train_set/points/._0007.mat
#   inflating: train_set/points/1319.mat
#   inflating: __MACOSX/train_set/points/._1319.mat
#   inflating: train_set/points/0761.mat
#   inflating: __MACOSX/train_set/points/._0761.mat
#   inflating: train_set/points/2176.mat
#   inflating: __MACOSX/train_set/points/._2176.mat
#   inflating: train_set/points/2162.mat
#   inflating: __MACOSX/train_set/points/._2162.mat
#   inflating: train_set/points/0775.mat
#   inflating: __MACOSX/train_set/points/._0775.mat
#   inflating: train_set/points/0013.mat
#   inflating: __MACOSX/train_set/points/._0013.mat
#   inflating: train_set/points/1325.mat
#   inflating: __MACOSX/train_set/points/._1325.mat
#   inflating: train_set/points/0985.mat
#   inflating: __MACOSX/train_set/points/._0985.mat
#   inflating: train_set/points/1443.mat
#   inflating: __MACOSX/train_set/points/._1443.mat
#   inflating: train_set/points/0991.mat
#   inflating: __MACOSX/train_set/points/._0991.mat
#   inflating: train_set/points/1457.mat
#   inflating: __MACOSX/train_set/points/._1457.mat
#   inflating: train_set/points/0749.mat
#   inflating: __MACOSX/train_set/points/._0749.mat
#   inflating: train_set/points/1331.mat
#   inflating: __MACOSX/train_set/points/._1331.mat
#   inflating: train_set/points/0946.mat
#   inflating: __MACOSX/train_set/points/._0946.mat
#   inflating: train_set/points/1480.mat
#   inflating: __MACOSX/train_set/points/._1480.mat
#   inflating: train_set/points/2189.mat
#   inflating: __MACOSX/train_set/points/._2189.mat
#   inflating: train_set/points/0952.mat
#   inflating: __MACOSX/train_set/points/._0952.mat
#   inflating: train_set/points/1494.mat
#   inflating: __MACOSX/train_set/points/._1494.mat
#   inflating: train_set/points/0173.mat
#   inflating: __MACOSX/train_set/points/._0173.mat
#   inflating: train_set/points/0615.mat
#   inflating: __MACOSX/train_set/points/._0615.mat
#   inflating: train_set/points/2002.mat
#   inflating: __MACOSX/train_set/points/._2002.mat
#   inflating: train_set/points/2016.mat
#   inflating: __MACOSX/train_set/points/._2016.mat
#   inflating: train_set/points/0601.mat
#   inflating: __MACOSX/train_set/points/._0601.mat
#   inflating: train_set/points/1279.mat
#   inflating: __MACOSX/train_set/points/._1279.mat
#   inflating: train_set/points/0167.mat
#   inflating: __MACOSX/train_set/points/._0167.mat
#   inflating: train_set/points/1251.mat
#   inflating: __MACOSX/train_set/points/._1251.mat
#   inflating: train_set/points/0629.mat
#   inflating: __MACOSX/train_set/points/._0629.mat
#   inflating: train_set/points/1537.mat
#   inflating: __MACOSX/train_set/points/._1537.mat
#   inflating: train_set/points/1523.mat
#   inflating: __MACOSX/train_set/points/._1523.mat
#   inflating: train_set/points/1245.mat
#   inflating: __MACOSX/train_set/points/._1245.mat
#   inflating: train_set/points/1292.mat
#   inflating: __MACOSX/train_set/points/._1292.mat
#   inflating: train_set/points/0832.mat
#   inflating: __MACOSX/train_set/points/._0832.mat
#   inflating: train_set/points/0826.mat
#   inflating: __MACOSX/train_set/points/._0826.mat
#   inflating: train_set/points/0198.mat
#   inflating: __MACOSX/train_set/points/._0198.mat
#   inflating: train_set/points/1286.mat
#   inflating: __MACOSX/train_set/points/._1286.mat
#   inflating: train_set/points/2200.mat
#   inflating: __MACOSX/train_set/points/._2200.mat
#   inflating: train_set/points/1709.mat
#   inflating: __MACOSX/train_set/points/._1709.mat
#   inflating: train_set/points/0417.mat
#   inflating: __MACOSX/train_set/points/._0417.mat
#   inflating: train_set/points/0371.mat
#   inflating: __MACOSX/train_set/points/._0371.mat
#   inflating: train_set/points/0365.mat
#   inflating: __MACOSX/train_set/points/._0365.mat
#   inflating: train_set/points/0403.mat
#   inflating: __MACOSX/train_set/points/._0403.mat
#   inflating: train_set/points/2214.mat
#   inflating: __MACOSX/train_set/points/._2214.mat
#   inflating: train_set/points/1735.mat
#   inflating: __MACOSX/train_set/points/._1735.mat
#   inflating: train_set/points/1053.mat
#   inflating: __MACOSX/train_set/points/._1053.mat
#   inflating: train_set/points/0359.mat
#   inflating: __MACOSX/train_set/points/._0359.mat
#   inflating: train_set/points/1047.mat
#   inflating: __MACOSX/train_set/points/._1047.mat
#   inflating: train_set/points/2228.mat
#   inflating: __MACOSX/train_set/points/._2228.mat
#   inflating: train_set/points/1721.mat
#   inflating: __MACOSX/train_set/points/._1721.mat
#   inflating: train_set/points/1912.mat
#   inflating: __MACOSX/train_set/points/._1912.mat
#   inflating: train_set/points/1906.mat
#   inflating: __MACOSX/train_set/points/._1906.mat
#   inflating: train_set/points/1090.mat
#   inflating: __MACOSX/train_set/points/._1090.mat
#   inflating: train_set/points/1084.mat
#   inflating: __MACOSX/train_set/points/._1084.mat
#   inflating: train_set/points/1092.mat
#   inflating: __MACOSX/train_set/points/._1092.mat
#   inflating: train_set/points/1938.mat
#   inflating: __MACOSX/train_set/points/._1938.mat
#   inflating: train_set/points/0398.mat
#   inflating: __MACOSX/train_set/points/._0398.mat
#   inflating: train_set/points/1086.mat
#   inflating: __MACOSX/train_set/points/._1086.mat
#   inflating: train_set/points/1910.mat
#   inflating: __MACOSX/train_set/points/._1910.mat
#   inflating: train_set/points/1904.mat
#   inflating: __MACOSX/train_set/points/._1904.mat
#   inflating: train_set/points/1051.mat
#   inflating: __MACOSX/train_set/points/._1051.mat
#   inflating: train_set/points/0429.mat
#   inflating: __MACOSX/train_set/points/._0429.mat
#   inflating: train_set/points/1737.mat
#   inflating: __MACOSX/train_set/points/._1737.mat
#   inflating: train_set/points/1723.mat
#   inflating: __MACOSX/train_set/points/._1723.mat
#   inflating: train_set/points/1045.mat
#   inflating: __MACOSX/train_set/points/._1045.mat
#   inflating: train_set/points/0373.mat
#   inflating: __MACOSX/train_set/points/._0373.mat
#   inflating: train_set/points/0415.mat
#   inflating: __MACOSX/train_set/points/._0415.mat
#   inflating: train_set/points/2202.mat
#   inflating: __MACOSX/train_set/points/._2202.mat
#   inflating: train_set/points/2216.mat
#   inflating: __MACOSX/train_set/points/._2216.mat
#   inflating: train_set/points/0401.mat
#   inflating: __MACOSX/train_set/points/._0401.mat
#   inflating: train_set/points/1079.mat
#   inflating: __MACOSX/train_set/points/._1079.mat
#   inflating: train_set/points/0367.mat
#   inflating: __MACOSX/train_set/points/._0367.mat
#   inflating: train_set/points/0830.mat
#   inflating: __MACOSX/train_set/points/._0830.mat
#   inflating: train_set/points/1290.mat
#   inflating: __MACOSX/train_set/points/._1290.mat
#   inflating: train_set/points/1284.mat
#   inflating: __MACOSX/train_set/points/._1284.mat
#   inflating: train_set/points/0824.mat
#   inflating: __MACOSX/train_set/points/._0824.mat
#   inflating: train_set/points/0818.mat
#   inflating: __MACOSX/train_set/points/._0818.mat
#   inflating: train_set/points/1535.mat
#   inflating: __MACOSX/train_set/points/._1535.mat
#   inflating: train_set/points/1253.mat
#   inflating: __MACOSX/train_set/points/._1253.mat
#   inflating: train_set/points/0159.mat
#   inflating: __MACOSX/train_set/points/._0159.mat
#   inflating: train_set/points/1247.mat
#   inflating: __MACOSX/train_set/points/._1247.mat
#   inflating: train_set/points/2028.mat
#   inflating: __MACOSX/train_set/points/._2028.mat
#   inflating: train_set/points/1521.mat
#   inflating: __MACOSX/train_set/points/._1521.mat
#   inflating: train_set/points/2000.mat
#   inflating: __MACOSX/train_set/points/._2000.mat
#   inflating: train_set/points/1509.mat
#   inflating: __MACOSX/train_set/points/._1509.mat
#   inflating: train_set/points/0617.mat
#   inflating: __MACOSX/train_set/points/._0617.mat
#   inflating: train_set/points/0171.mat
#   inflating: __MACOSX/train_set/points/._0171.mat
#   inflating: train_set/points/0165.mat
#   inflating: __MACOSX/train_set/points/._0165.mat
#   inflating: train_set/points/0603.mat
#   inflating: __MACOSX/train_set/points/._0603.mat
#   inflating: train_set/points/2014.mat
#   inflating: __MACOSX/train_set/points/._2014.mat
#   inflating: train_set/points/1482.mat
#   inflating: __MACOSX/train_set/points/._1482.mat
#   inflating: train_set/points/0944.mat
#   inflating: __MACOSX/train_set/points/._0944.mat
#   inflating: train_set/points/1496.mat
#   inflating: __MACOSX/train_set/points/._1496.mat
#   inflating: train_set/points/0950.mat
#   inflating: __MACOSX/train_set/points/._0950.mat
#   inflating: train_set/points/0788.mat
#   inflating: __MACOSX/train_set/points/._0788.mat
#   inflating: train_set/points/0978.mat
#   inflating: __MACOSX/train_set/points/._0978.mat
#   inflating: train_set/points/1441.mat
#   inflating: __MACOSX/train_set/points/._1441.mat
#   inflating: train_set/points/0987.mat
#   inflating: __MACOSX/train_set/points/._0987.mat
#   inflating: train_set/points/2148.mat
#   inflating: __MACOSX/train_set/points/._2148.mat
#   inflating: train_set/points/1327.mat
#   inflating: __MACOSX/train_set/points/._1327.mat
#   inflating: train_set/points/0039.mat
#   inflating: __MACOSX/train_set/points/._0039.mat
#   inflating: train_set/points/1333.mat
#   inflating: __MACOSX/train_set/points/._1333.mat
#   inflating: train_set/points/1455.mat
#   inflating: __MACOSX/train_set/points/._1455.mat
#   inflating: train_set/points/0993.mat
#   inflating: __MACOSX/train_set/points/._0993.mat
#   inflating: train_set/points/2174.mat
#   inflating: __MACOSX/train_set/points/._2174.mat
#   inflating: train_set/points/0763.mat
#   inflating: __MACOSX/train_set/points/._0763.mat
#   inflating: train_set/points/0005.mat
#   inflating: __MACOSX/train_set/points/._0005.mat
#   inflating: train_set/points/0011.mat
#   inflating: __MACOSX/train_set/points/._0011.mat
#   inflating: train_set/points/0777.mat
#   inflating: __MACOSX/train_set/points/._0777.mat
#   inflating: train_set/points/1469.mat
#   inflating: __MACOSX/train_set/points/._1469.mat
#   inflating: train_set/points/2160.mat
#   inflating: __MACOSX/train_set/points/._2160.mat
#   inflating: train_set/points/1858.mat
#   inflating: __MACOSX/train_set/points/._1858.mat
#   inflating: train_set/points/1680.mat
#   inflating: __MACOSX/train_set/points/._1680.mat
#   inflating: train_set/points/2389.mat
#   inflating: __MACOSX/train_set/points/._2389.mat
#   inflating: train_set/points/1694.mat
#   inflating: __MACOSX/train_set/points/._1694.mat
#   inflating: train_set/points/1864.mat
#   inflating: __MACOSX/train_set/points/._1864.mat
#   inflating: train_set/points/1870.mat
#   inflating: __MACOSX/train_set/points/._1870.mat
#   inflating: train_set/points/1125.mat
#   inflating: __MACOSX/train_set/points/._1125.mat
#   inflating: train_set/points/1643.mat
#   inflating: __MACOSX/train_set/points/._1643.mat
#   inflating: train_set/points/1657.mat
#   inflating: __MACOSX/train_set/points/._1657.mat
# ...
#   inflating: train_set/points/0378.mat
#   inflating: __MACOSX/train_set/points/._0378.mat
#   inflating: train_set/points/1066.mat
#   inflating: __MACOSX/train_set/points/._1066.mat
#   inflating: train_set/points/1700.mat
#   inflating: __MACOSX/train_set/points/._1700.mat
#   inflating: train_set/points/2209.mat
#   inflating: __MACOSX/train_set/points/._2209.mat
#   inflating: train_set/points/1933.mat
#   inflating: __MACOSX/train_set/points/._1933.mat
#   inflating: train_set/points/0393.mat
#   inflating: __MACOSX/train_set/points/._0393.mat
#   inflating: train_set/points/1099.mat
#   inflating: __MACOSX/train_set/points/._1099.mat
#   inflating: train_set/points/0387.mat
#   inflating: __MACOSX/train_set/points/._0387.mat
#   inflating: train_set/points/1927.mat
#   inflating: __MACOSX/train_set/points/._1927.mat
#   inflating: train_set/points/1919.mat
#   inflating: __MACOSX/train_set/points/._1919.mat
#   inflating: train_set/points/0391.mat
#   inflating: __MACOSX/train_set/points/._0391.mat
#   inflating: train_set/points/1931.mat
#   inflating: __MACOSX/train_set/points/._1931.mat
#   inflating: train_set/points/1925.mat
#   inflating: __MACOSX/train_set/points/._1925.mat
#   inflating: train_set/points/0385.mat
#   inflating: __MACOSX/train_set/points/._0385.mat
#   inflating: train_set/points/1070.mat
#   inflating: __MACOSX/train_set/points/._1070.mat
#   inflating: train_set/points/0408.mat
#   inflating: __MACOSX/train_set/points/._0408.mat
#   inflating: train_set/points/1716.mat
#   inflating: __MACOSX/train_set/points/._1716.mat
#   inflating: train_set/points/1702.mat
#   inflating: __MACOSX/train_set/points/._1702.mat
#   inflating: train_set/points/1064.mat
#   inflating: __MACOSX/train_set/points/._1064.mat
#   inflating: train_set/points/0352.mat
#   inflating: __MACOSX/train_set/points/._0352.mat
#   inflating: train_set/points/2223.mat
#   inflating: __MACOSX/train_set/points/._2223.mat
#   inflating: train_set/points/0434.mat
#   inflating: __MACOSX/train_set/points/._0434.mat
#   inflating: train_set/points/0420.mat
#   inflating: __MACOSX/train_set/points/._0420.mat
#   inflating: train_set/points/2237.mat
#   inflating: __MACOSX/train_set/points/._2237.mat
#   inflating: train_set/points/1058.mat
#   inflating: __MACOSX/train_set/points/._1058.mat
#   inflating: train_set/points/0346.mat
#   inflating: __MACOSX/train_set/points/._0346.mat
#   inflating: train_set/points/0811.mat
#   inflating: __MACOSX/train_set/points/._0811.mat
#   inflating: train_set/points/0805.mat
#   inflating: __MACOSX/train_set/points/._0805.mat
#   inflating: train_set/points/0193.mat
#   inflating: __MACOSX/train_set/points/._0193.mat
#   inflating: train_set/points/1299.mat
#   inflating: __MACOSX/train_set/points/._1299.mat
#   inflating: train_set/points/0187.mat
#   inflating: __MACOSX/train_set/points/._0187.mat
#   inflating: train_set/points/0839.mat
#   inflating: __MACOSX/train_set/points/._0839.mat
#   inflating: train_set/points/1514.mat
#   inflating: __MACOSX/train_set/points/._1514.mat
#   inflating: train_set/points/1272.mat
#   inflating: __MACOSX/train_set/points/._1272.mat
#   inflating: train_set/points/0178.mat
#   inflating: __MACOSX/train_set/points/._0178.mat
#   inflating: train_set/points/1266.mat
#   inflating: __MACOSX/train_set/points/._1266.mat
#   inflating: train_set/points/1500.mat
#   inflating: __MACOSX/train_set/points/._1500.mat
#   inflating: train_set/points/2009.mat
#   inflating: __MACOSX/train_set/points/._2009.mat
#   inflating: train_set/points/1528.mat
#   inflating: __MACOSX/train_set/points/._1528.mat
#   inflating: train_set/points/0636.mat
#   inflating: __MACOSX/train_set/points/._0636.mat
#   inflating: train_set/points/2021.mat
#   inflating: __MACOSX/train_set/points/._2021.mat
#   inflating: train_set/points/0150.mat
#   inflating: __MACOSX/train_set/points/._0150.mat
#   inflating: train_set/points/0144.mat
#   inflating: __MACOSX/train_set/points/._0144.mat
#   inflating: train_set/points/2035.mat
#   inflating: __MACOSX/train_set/points/._2035.mat
#   inflating: train_set/points/0622.mat
#   inflating: __MACOSX/train_set/points/._0622.mat
#   inflating: train_set/points/0965.mat
#   inflating: __MACOSX/train_set/points/._0965.mat
#   inflating: train_set/points/0971.mat
#   inflating: __MACOSX/train_set/points/._0971.mat
#   inflating: train_set/points/2196.mat
#   inflating: __MACOSX/train_set/points/._2196.mat
#   inflating: train_set/points/0959.mat
#   inflating: __MACOSX/train_set/points/._0959.mat
#   inflating: train_set/points/0781.mat
#   inflating: __MACOSX/train_set/points/._0781.mat
#   inflating: train_set/points/0795.mat
#   inflating: __MACOSX/train_set/points/._0795.mat
#   inflating: train_set/points/2182.mat
#   inflating: __MACOSX/train_set/points/._2182.mat
#   inflating: train_set/points/2169.mat
#   inflating: __MACOSX/train_set/points/._2169.mat
#   inflating: train_set/points/1460.mat
#   inflating: __MACOSX/train_set/points/._1460.mat
#   inflating: train_set/points/1306.mat
#   inflating: __MACOSX/train_set/points/._1306.mat
#   inflating: train_set/points/0018.mat
#   inflating: __MACOSX/train_set/points/._0018.mat
#   inflating: train_set/points/1312.mat
#   inflating: __MACOSX/train_set/points/._1312.mat
#   inflating: train_set/points/1474.mat
#   inflating: __MACOSX/train_set/points/._1474.mat
#   inflating: train_set/points/0742.mat
#   inflating: __MACOSX/train_set/points/._0742.mat
#   inflating: train_set/points/2155.mat
#   inflating: __MACOSX/train_set/points/._2155.mat
#   inflating: train_set/points/0024.mat
#   inflating: __MACOSX/train_set/points/._0024.mat
#   inflating: train_set/points/0030.mat
#   inflating: __MACOSX/train_set/points/._0030.mat
#   inflating: train_set/points/2141.mat
#   inflating: __MACOSX/train_set/points/._2141.mat
#   inflating: train_set/points/0756.mat
#   inflating: __MACOSX/train_set/points/._0756.mat
#   inflating: train_set/points/1448.mat
#   inflating: __MACOSX/train_set/points/._1448.mat
#   inflating: train_set/points/1879.mat
#   inflating: __MACOSX/train_set/points/._1879.mat
#   inflating: train_set/points/0583.mat
#   inflating: __MACOSX/train_set/points/._0583.mat
#   inflating: train_set/points/1845.mat
#   inflating: __MACOSX/train_set/points/._1845.mat
#   inflating: train_set/points/2394.mat
#   inflating: __MACOSX/train_set/points/._2394.mat
#   inflating: train_set/points/2380.mat
#   inflating: __MACOSX/train_set/points/._2380.mat
#   inflating: train_set/points/0597.mat
#   inflating: __MACOSX/train_set/points/._0597.mat
#   inflating: train_set/points/1851.mat
#   inflating: __MACOSX/train_set/points/._1851.mat
#   inflating: train_set/points/1689.mat
#   inflating: __MACOSX/train_set/points/._1689.mat
#   inflating: train_set/points/1104.mat
#   inflating: __MACOSX/train_set/points/._1104.mat
#   inflating: train_set/points/1662.mat
#   inflating: __MACOSX/train_set/points/._1662.mat
#   inflating: train_set/points/1676.mat
#   inflating: __MACOSX/train_set/points/._1676.mat
#   inflating: train_set/points/0568.mat
#   inflating: __MACOSX/train_set/points/._0568.mat
#   inflating: train_set/points/1110.mat
#   inflating: __MACOSX/train_set/points/._1110.mat
#   inflating: train_set/points/2419.mat
#   inflating: __MACOSX/train_set/points/._2419.mat
#   inflating: train_set/points/0226.mat
#   inflating: __MACOSX/train_set/points/._0226.mat
#   inflating: train_set/points/1138.mat
#   inflating: __MACOSX/train_set/points/._1138.mat
#   inflating: train_set/points/2431.mat
#   inflating: __MACOSX/train_set/points/._2431.mat
#   inflating: train_set/points/2357.mat
#   inflating: __MACOSX/train_set/points/._2357.mat
#   inflating: train_set/points/0540.mat
#   inflating: __MACOSX/train_set/points/._0540.mat
#   inflating: train_set/points/1886.mat
#   inflating: __MACOSX/train_set/points/._1886.mat
#   inflating: train_set/points/0554.mat
#   inflating: __MACOSX/train_set/points/._0554.mat
#   inflating: train_set/points/1892.mat
#   inflating: __MACOSX/train_set/points/._1892.mat
#   inflating: train_set/points/2343.mat
#   inflating: __MACOSX/train_set/points/._2343.mat
#   inflating: train_set/points/2425.mat
#   inflating: __MACOSX/train_set/points/._2425.mat
#   inflating: train_set/points/0232.mat
#   inflating: __MACOSX/train_set/points/._0232.mat
#   inflating: train_set/points/2342.mat
#   inflating: __MACOSX/train_set/points/._2342.mat
#   inflating: train_set/points/1893.mat
#   inflating: __MACOSX/train_set/points/._1893.mat
#   inflating: train_set/points/0555.mat
#   inflating: __MACOSX/train_set/points/._0555.mat
#   inflating: train_set/points/0233.mat
#   inflating: __MACOSX/train_set/points/._0233.mat
#   inflating: train_set/points/2424.mat
#   inflating: __MACOSX/train_set/points/._2424.mat
#   inflating: train_set/points/2430.mat
#   inflating: __MACOSX/train_set/points/._2430.mat
#   inflating: train_set/points/1139.mat
#   inflating: __MACOSX/train_set/points/._1139.mat
#   inflating: train_set/points/0227.mat
#   inflating: __MACOSX/train_set/points/._0227.mat
#   inflating: train_set/points/1887.mat
#   inflating: __MACOSX/train_set/points/._1887.mat
#   inflating: train_set/points/0541.mat
#   inflating: __MACOSX/train_set/points/._0541.mat
#   inflating: train_set/points/2356.mat
#   inflating: __MACOSX/train_set/points/._2356.mat
#   inflating: train_set/points/0569.mat
#   inflating: __MACOSX/train_set/points/._0569.mat
#   inflating: train_set/points/1677.mat
#   inflating: __MACOSX/train_set/points/._1677.mat
#   inflating: train_set/points/2418.mat
#   inflating: __MACOSX/train_set/points/._2418.mat
#   inflating: train_set/points/1111.mat
#   inflating: __MACOSX/train_set/points/._1111.mat
#   inflating: train_set/points/1105.mat
#   inflating: __MACOSX/train_set/points/._1105.mat
#   inflating: train_set/points/1663.mat
#   inflating: __MACOSX/train_set/points/._1663.mat
#   inflating: train_set/points/1688.mat
#   inflating: __MACOSX/train_set/points/._1688.mat
#   inflating: train_set/points/1850.mat
#   inflating: __MACOSX/train_set/points/._1850.mat
#   inflating: train_set/points/0596.mat
#   inflating: __MACOSX/train_set/points/._0596.mat
#   inflating: train_set/points/2381.mat
#   inflating: __MACOSX/train_set/points/._2381.mat
#   inflating: train_set/points/2395.mat
#   inflating: __MACOSX/train_set/points/._2395.mat
#   inflating: train_set/points/1844.mat
#   inflating: __MACOSX/train_set/points/._1844.mat
#   inflating: train_set/points/0582.mat
#   inflating: __MACOSX/train_set/points/._0582.mat
#   inflating: train_set/points/1878.mat
#   inflating: __MACOSX/train_set/points/._1878.mat
#   inflating: train_set/points/0031.mat
#   inflating: __MACOSX/train_set/points/._0031.mat
#   inflating: train_set/points/1449.mat
#   inflating: __MACOSX/train_set/points/._1449.mat
#   inflating: train_set/points/0757.mat
#   inflating: __MACOSX/train_set/points/._0757.mat
#   inflating: train_set/points/2140.mat
#   inflating: __MACOSX/train_set/points/._2140.mat
#   inflating: train_set/points/2154.mat
#   inflating: __MACOSX/train_set/points/._2154.mat
#   inflating: train_set/points/0743.mat
#   inflating: __MACOSX/train_set/points/._0743.mat
#   inflating: train_set/points/0025.mat
#   inflating: __MACOSX/train_set/points/._0025.mat
#   inflating: train_set/points/1313.mat
#   inflating: __MACOSX/train_set/points/._1313.mat
#   inflating: train_set/points/1475.mat
#   inflating: __MACOSX/train_set/points/._1475.mat
#   inflating: train_set/points/1461.mat
#   inflating: __MACOSX/train_set/points/._1461.mat
#   inflating: train_set/points/2168.mat
#   inflating: __MACOSX/train_set/points/._2168.mat
#   inflating: train_set/points/0019.mat
#   inflating: __MACOSX/train_set/points/._0019.mat
#   inflating: train_set/points/1307.mat
#   inflating: __MACOSX/train_set/points/._1307.mat
#   inflating: train_set/points/2183.mat
#   inflating: __MACOSX/train_set/points/._2183.mat
#   inflating: train_set/points/0794.mat
#   inflating: __MACOSX/train_set/points/._0794.mat
#   inflating: train_set/points/0780.mat
#   inflating: __MACOSX/train_set/points/._0780.mat
#   inflating: train_set/points/0958.mat
#   inflating: __MACOSX/train_set/points/._0958.mat
#   inflating: train_set/points/2197.mat
#   inflating: __MACOSX/train_set/points/._2197.mat
#   inflating: train_set/points/0970.mat
#   inflating: __MACOSX/train_set/points/._0970.mat
#   inflating: train_set/points/0964.mat
#   inflating: __MACOSX/train_set/points/._0964.mat
#   inflating: train_set/points/0145.mat
#   inflating: __MACOSX/train_set/points/._0145.mat
#   inflating: train_set/points/0623.mat
#   inflating: __MACOSX/train_set/points/._0623.mat
#   inflating: train_set/points/2034.mat
#   inflating: __MACOSX/train_set/points/._2034.mat
#   inflating: train_set/points/2020.mat
#   inflating: __MACOSX/train_set/points/._2020.mat
#   inflating: train_set/points/0637.mat
#   inflating: __MACOSX/train_set/points/._0637.mat
#   inflating: train_set/points/1529.mat
#   inflating: __MACOSX/train_set/points/._1529.mat
#   inflating: train_set/points/0151.mat
#   inflating: __MACOSX/train_set/points/._0151.mat
#   inflating: train_set/points/1267.mat
#   inflating: __MACOSX/train_set/points/._1267.mat
#   inflating: train_set/points/0179.mat
#   inflating: __MACOSX/train_set/points/._0179.mat
#   inflating: train_set/points/2008.mat
#   inflating: __MACOSX/train_set/points/._2008.mat
#   inflating: train_set/points/1501.mat
#   inflating: __MACOSX/train_set/points/._1501.mat
#   inflating: train_set/points/1515.mat
#   inflating: __MACOSX/train_set/points/._1515.mat
#   inflating: train_set/points/1273.mat
#   inflating: __MACOSX/train_set/points/._1273.mat
#   inflating: train_set/points/0186.mat
#   inflating: __MACOSX/train_set/points/._0186.mat
#   inflating: train_set/points/1298.mat
#   inflating: __MACOSX/train_set/points/._1298.mat
#   inflating: train_set/points/0838.mat
#   inflating: __MACOSX/train_set/points/._0838.mat
#   inflating: train_set/points/0192.mat
#   inflating: __MACOSX/train_set/points/._0192.mat
#   inflating: train_set/points/0804.mat
#   inflating: __MACOSX/train_set/points/._0804.mat
#   inflating: train_set/points/0810.mat
#   inflating: __MACOSX/train_set/points/._0810.mat
#   inflating: train_set/points/2236.mat
#   inflating: __MACOSX/train_set/points/._2236.mat
#   inflating: train_set/points/0421.mat
#   inflating: __MACOSX/train_set/points/._0421.mat
#   inflating: train_set/points/0347.mat
#   inflating: __MACOSX/train_set/points/._0347.mat
#   inflating: train_set/points/1059.mat
#   inflating: __MACOSX/train_set/points/._1059.mat
#   inflating: train_set/points/0353.mat
#   inflating: __MACOSX/train_set/points/._0353.mat
#   inflating: train_set/points/0435.mat
#   inflating: __MACOSX/train_set/points/._0435.mat
#   inflating: train_set/points/2222.mat
#   inflating: __MACOSX/train_set/points/._2222.mat
#   inflating: train_set/points/1703.mat
#   inflating: __MACOSX/train_set/points/._1703.mat
#   inflating: train_set/points/1065.mat
#   inflating: __MACOSX/train_set/points/._1065.mat
#   inflating: train_set/points/1071.mat
#   inflating: __MACOSX/train_set/points/._1071.mat
#   inflating: train_set/points/1717.mat
#   inflating: __MACOSX/train_set/points/._1717.mat
#   inflating: train_set/points/0409.mat
#   inflating: __MACOSX/train_set/points/._0409.mat
#   inflating: train_set/points/1924.mat
#   inflating: __MACOSX/train_set/points/._1924.mat
#   inflating: train_set/points/0384.mat
#   inflating: __MACOSX/train_set/points/._0384.mat
#   inflating: train_set/points/0390.mat
#   inflating: __MACOSX/train_set/points/._0390.mat
#   inflating: train_set/points/1930.mat
#   inflating: __MACOSX/train_set/points/._1930.mat
#   inflating: train_set/points/1918.mat
#   inflating: __MACOSX/train_set/points/._1918.mat
#   inflating: __MACOSX/train_set/._points
#   inflating: __MACOSX/._train_set

# %%
#####Run the code, and go to the URL in th output, enter the authorization code, done
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # I. Our Advanced Model

# %% [markdown]
# We are using PCA with Bagging-SVM as our Advacned Model

# %% [markdown]
# Notation on These functions:
# 1. extract_mat():
#
#   **TAKES IN** a list returned by a loadmat function.
#
#   **RETURN** an array that have all the points in the mat file.
#
# 2. get_f():
#
#   **TAKES IN** a direction that contains a _single_ .mat file.
#
#   **RETURN** an ndarray contains the pairwise euclidian distance between the coordinate contains in the .mat file.
#
# 3. feature_extraction():
#
#   **TAKES IN** a direction that contains the direction that contains _all_ the .mat file for the train.
#
#   **RETURNS** a ndarray contains the train_x with features set as pairwise euclidian distance between the coordinate contains in the .mat file.
#
# 4. f_pca():
#
#   **TAKES IN** a ndarray contains all the train_x.
#
#   **RETURNS** a ndarray contains decomposed x and the decompositon model.
#
# 5. BaggingSVM_w_pca():
#
#   **TAKES IN** two ndarrays as train_x(without decomposition) and train_y.
#
#   **RETURNS** the SVM-Bagging model trained with decomposed-train_x and train_y.
#
# 6. claim_possible_acc_BSVM():
#
#   **TAKES IN** three arguments which is the direction that contains _all_the .mat file for x, the direction that contains a file named *label.csv* that have a column named as emotion_idx as the train_y.
#
#   **RETURNS** the possible accuracy of the Logistic-Bagging model.

# %%
def extract_mat(x):
    v = list(x.keys())[-1]
    return x[v]

def get_f(file_dir):
    '''Argument: 
        file_dir: The whole direction contain the exact mat file
       
       Return:
        a np.array contains the featrues of single X'''
    a = extract_mat(loadmat(file_dir))
    b = cdist(a, a)
    r = b[np.triu_indices(b.shape[1], 1)].flatten()
    return r

def f_pca(x):
    my_pca = PCA(n_components = 130)
    new_X = my_pca.fit_transform(x)
    compo = sum(my_pca.explained_variance_ratio_)
    print(f'The Decomposition take up {compo: 0.2f}% Information of original Data')
    
    return new_X, my_pca

def feature_extraction(dir_x):
    if (dir_x[-1] != '/'):
        dir_x = dir_x + '/'
    
    fea_start = time.time()
    
    filenames = list(os.listdir(dir_x))
    filenames.sort()
    X = np.array(list(map(get_f, ((dir_x + i) for i in filenames))))
    
    fea_end = time.time()
    fea_time = fea_end - fea_start
    
    print('Feature Extraction Completed!')
    print(f'Feature Extraction Cost: {fea_time: 0.2f} Seconds')
    return X

def BaggingSVM_w_pca(train_X, train_y):
    
    train_X, pca_mode = f_pca(train_X)    
    
    start_SVM = time.time()
    S_svm = SVC(C = 0.1,
                kernel = 'linear',
                shrinking = True,
                decision_function_shape = 'ovo')
    Bagg_SVM = BaggingClassifier(S_svm,
                                 n_estimators = 80,
                                 n_jobs = 5,
                                 bootstrap_features = True)
    Bagg_SVM.fit(train_X, train_y)
    end_SVM = time.time()
    
    Train_time = end_SVM - start_SVM
    print(f'The Time for train is: {Train_time: 0.2f} Seconds')
    return Bagg_SVM, pca_mode


def claim_possible_acc_BSVM(X_path, y_path, n_iter = 1):
    X = feature_extraction(X_path)
    y = pd.read_csv(y_path).emotion_idx
    
    accs = []
    for i in range(n_iter):
        trainx, testx, trainy, testy = train_test_split(X, y, test_size = .2)
        model, pca_mode= BaggingSVM_w_pca(trainx, trainy)
        new_testx = pca_mode.transform(testx)
        testy_hat = model.predict(new_testx)
        accs.append(accuracy_score(testy, testy_hat))
    return np.mean(accs)

# %%
# This line can output the Claimed Accuracy
# You don't really need run it
# claim_possible_acc_BSVM('train_set/points', 'train_set/label.csv', 5)
# Out:
# Feature Extraction Completed!
# Feature Extraction Cost:  0.95 Seconds
# The Decomposition take up  1.00% Information of original Data
# The Time for train is:  127.39 Seconds
# The Decomposition take up  1.00% Information of original Data
# The Time for train is:  109.33 Seconds
# The Decomposition take up  1.00% Information of original Data
# The Time for train is:  115.86 Seconds
# The Decomposition take up  1.00% Information of original Data
# The Time for train is:  133.65 Seconds
# The Decomposition take up  1.00% Information of original Data
# The Time for train is:  112.68 Seconds
# 0.5256000000000001

# %% [markdown]
# Our Advanced Model would have 52.56% Accuracy.
#
# The train time for our Advanced Model is about 110 seconds

# %% [markdown]
# You can use The Code below to train the model on the whole train data set

# %%
X = feature_extraction('train_set/points')
y = pd.read_csv('train_set/label.csv').emotion_idx
advanced_model, pca_sub_model = BaggingSVM_w_pca(X, y)
# Out:
# Feature Extraction Completed!
# Feature Extraction Cost:  0.82 Seconds
# The Decomposition take up  1.00% Information of original Data
# The Time for train is:  322.94 Seconds

# %% [markdown]
# Then, you can use the code below to test on the test set

# %%
# X_test = feature_extraction('''your test set direction''')
# X_test_decomp = pca_sub_model.transform(X_test)
# y_predict = advanced_model.predict(X_test_decomp)

# %% [markdown]
# # II. XGBOOST Model

# %% [markdown]
# ## Part 0: Feature Extration and Train/Test Split

# %%
##### Importing the fidusial points 
import scipy.io as scio
from collections import OrderedDict 
points_path = 'train_set/points'
points = [p for p in sorted(os.listdir(points_path))]
all_points = []
for p in points:
  poiFile = os.path.join(points_path, p)
  poi = scio.loadmat(poiFile)
  poi = OrderedDict(poi)
  all_points.append(poi.popitem()[1])
y = pd.read_csv('train_set/label.csv')['emotion_idx']

print('success')
# Out:
# success

# %%
##### Calculating pairwise distance 
pair_dist = []
for i in range(len(all_points)):
  pair_dist.append(metrics.pairwise_distances(all_points[i])[np.triu_indices(78)])

##### Split train_set & test_set 
points_train, points_test, y_train, y_test = train_test_split(pair_dist, y, random_state=42, test_size=0.2)
print('success')
# Out:
# success

# %%
##### Feature Extration/Calculating pairwise distance and the time for feature extration 
import time

allpoints_train, allpoints_test, y_train, y_test = train_test_split(all_points, y, random_state=42, test_size=0.2)
print('success')


train_pair_dist = []
for i in range(len(allpoints_train)):
  pair_dist.append(metrics.pairwise_distances(allpoints_train[i])[np.triu_indices(78)])

test_pair_dist = []
for i in range(len(allpoints_test)):
  pair_dist.append(metrics.pairwise_distances(allpoints_test[i])[np.triu_indices(78)])


start = time.time()
pair_dist = []
for i in range(len(all_points)):
  pair_dist.append(metrics.pairwise_distances(all_points[i])[np.triu_indices(78)])
finish = time.time()
print("Time on feature selection done in %0.3fs" % (finish-start))

start = time.time()
train_pair_dist = []
for i in range(len(allpoints_train)):
  pair_dist.append(metrics.pairwise_distances(allpoints_train[i])[np.triu_indices(78)])
finish = time.time()
print("Time on feature selection training set done in %0.3fs" % (finish-start))

start = time.time()
test_pair_dist = []
for i in range(len(allpoints_test)):
  pair_dist.append(metrics.pairwise_distances(allpoints_test[i])[np.triu_indices(78)])
finish = time.time()
print("Time on feature selection test set done in %0.3fs" % (finish-start))
# Out:
# success
# Time on feature selection done in 1.098s
# Time on feature selection training set done in 0.922s
# Time on feature selection test set done in 0.277s

# %% [markdown]
# ## Part 1: XGBoost Training

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from xgboost.sklearn import XGBClassifier
import time
import numpy as np

# %%
def modelfit(alg, dtrain, predictors, cv_folds=10):
  #Fit the algorithm on the data
  alg.fit(dtrain, predictors)

  #Predict training set:
  dtrain_predictions = alg.predict(dtrain)
  dtrain_predprob = alg.predict_proba(dtrain)[:,1]

  #Print model report:
  print("\nModel Report")
  print("Accuracy : %.4g" % metrics.accuracy_score(predictors, dtrain_predictions))

# %% [markdown]
# ## Part 2:XGBoost Default setting

# %%
####XGBOOST base model with default setting
start = time.time()
xgb_base = XGBClassifier(
 objective= 'multi:softmax',
 num_class= 22,
 seed=1000)

modelfit(xgb_base, np.array(points_train), np.array(y_train))
finish = time.time()
print("Prediction on train_set done in %0.3fs" % (finish-start))
# Out:
# Model Report
# Accuracy : 1
# Prediction on train_set done in 807.874s

# %%
start = time.time()
preds = xgb_base.predict(points_test)
acc_preds = metrics.accuracy_score(preds, y_test)
finish = time.time()
print("Prediction on test_set done in %0.3fs" % (finish - start))
print("Test_set accurarcy is %0.3f" %acc_preds)
# Out:
# Prediction on test_set done in 0.740s
# Test_set accurarcy is 0.482

# %% [markdown]
# ### Tuning Process(comment it out because the process is time comsuming)

# %%
####tune hyperparameter

## tune the max_depth and min_child_weight parameter
# param_test1 = { 
#  'max_depth': range(4,5,6),
#  'min_child_weight': range(4,5,6)
# } 
# gsearch1 = GridSearchCV(xgb_base, param_grid = param_test1, scoring ='accuracy', cv = 5)
# gsearch1.fit(np.array(points_train), np.array(y_train))
# best_parameters1 = gsearch1.best_estimator_.get_params()
# for param_name in sorted(param_test1.keys()):
#     print("\t%s: %r" % (param_name, best_parameters1[param_name]))

## use the best_parameter above to xgb2
# start = time.time()
# xgb2 = XGBClassifier(
#  objective= 'multi:softmax',
#  num_class= 22,
#  max_depth=4,
#  min_child_weight=4,
#  seed=1000)
# modelfit(xgb2, np.array(points_train), np.array(y_train))
# finish = time.time()
# print("Prediction on train_set done in %0.3fs" % (finish-start))
# start = time.time()
# preds = xgb2.predict(points_test)
# acc_pred = metrics.accuracy_score(preds, y_test)
# finish = time.time()
# print("Prediction on test_set done in %0.3fs" % (finish - start))
# print("Test_set accurarcy is %0.3f" %acc_pred)

## However, the accuracy is lower than that of the base model, so we keep the same parameter 
## as before, and tune other parameters.

## tune the gamma parameter
# param_test2 = { 
#  'gamma':[i/10.0 for i in range(0,5)]
# } 
# gsearch2 = GridSearchCV(xgb1, param_grid = param_test2, scoring ='accuracy', cv = 5)
# gsearch2.fit(np.array(points_train), np.array(y_train))
# best_parameters2 = gsearch2.best_estimator_.get_params()
# for param_name in sorted(param_test2.keys()):
#     print("\t%s: %r" % (param_name, best_parameters2[param_name]))

# start = time.time()
# xgb3 = XGBClassifier(
#  objective= 'multi:softmax',
#  num_class= 22,
#  gamma=0.4,
#  seed=1000)

# modelfit(xgb3, np.array(points_train), np.array(y_train))
# finish = time.time()
# print("Prediction on train_set done in %0.3fs" % (finish-start))

# start = time.time()
# preds = xgb3.predict(points_test)
# acc_pred = metrics.accuracy_score(preds, y_test)
# finish = time.time()
# print("Prediction on test_set done in %0.3fs" % (finish - start))
# print("Test_set accurarcy is %0.3f" %acc_pred)

## However, the accuracy is lower than that of the base model, so we keep the same parameter 
## as before, and tune other parameters.

## tune the subsample and colsample_bytree parameters
#param_test = {
 #'subsample':[i/10.0 for i in range(6,10)],
 #'colsample_bytree':[i/10.0 for i in range(6,10)]
#}
#gsearch = GridSearchCV(xgb_base, param_grid = param_test, scoring ='accuracy', cv = 5)
#gsearch.fit(np.array(points_train), np.array(y_train))
#best_parameters = gsearch.best_estimator_.get_params()
#for param_name in sorted(param_test.keys()):
    #print("\t%s: %r" % (param_name, best_parameters[param_name]))

# start = time.time()
# xgb4 = XGBClassifier(
#  objective = 'multi:softmax',
#  num_class = 22,
#  seed = 1000,
#  colsample_bytree=0.6,
#  subsample=0.7)

# modelfit(xgb4, np.array(points_train), np.array(y_train))
# finish = time.time()
# print("Prediction on train_set done in %0.3fs" % (finish-start)) 

# start = time.time()
# preds = xgb4.predict(points_test)
# acc_pred = metrics.accuracy_score(preds, y_test)
# finish = time.time()
# print("Prediction on test_set done in %0.3fs" % (finish - start))
# print("Test_set accurarcy is %0.3f" %acc_pred)

## We use the best parameters above because the accuracy increases and the prediction time 
## decreases. Then, we tune other parameter based on the xgb4.

##tune reg_alpha parameter
#param_test4 = {
#  'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]
# }
# gsearch4 = GridSearchCV(xgb4, param_grid = param_test4, scoring ='accuracy', cv = 5)
# gsearch4.fit(np.array(points_train), np.array(y_train))
# best_parameters4 = gsearch4.best_estimator_.get_params()
# for param_name in sorted(param_test4.keys()):
#     print("\t%s: %r" % (param_name, best_parameters4[param_name]))

# start = time.time()
# xgb5 = XGBClassifier(
#  objective= 'multi:softmax',
#  num_class= 22,
#  seed=1000,
#  colsample_bytree=0.7,
#  subsample=0.6,
#  reg_alpha=1)

# modelfit(xgb5, np.array(points_train), np.array(y_train))
# finish = time.time()
# print("Prediction on train_set done in %0.3fs" % (finish-start)) 

# start = time.time()
# preds = xgb5.predict(points_test)
# acc_pred = metrics.accuracy_score(preds, y_test)
# finish = time.time()
# print("Prediction on test_set done in %0.3fs" % (finish - start))
# print("Test_set accurarcy is %0.3f" %acc_pred)

##Since the best parameter of reg_alpha=1e-05, and the accuracy is so close to that of the former 
##model, we decide to use the xgb5 as our final model.

# %% [markdown]
# ## Part 3: The improved XGboost model after tuning the parameters

# %%
####XGBOOSTING improved model
start = time.time()
xgb5 = XGBClassifier(
 objective= 'multi:softmax',
 num_class= 22,
 seed=1000,
 colsample_bytree=0.6,
 subsample=0.7,
 reg_alpha=1)

modelfit(xgb5, np.array(points_train), np.array(y_train))
finish = time.time()
print("Prediction on train_set done in %0.3fs" % (finish-start))
# Out:
# Model Report
# Accuracy : 0.9995
# Prediction on train_set done in 483.013s

# %%
start = time.time()
preds = xgb5.predict(points_test)
acc_pred = metrics.accuracy_score(preds, y_test)
finish = time.time()
print("Prediction on test_set done in %0.3fs" % (finish - start))
print("Test_set accurarcy is %0.3f" %acc_pred)
# Out:
# Prediction on test_set done in 0.770s
# Test_set accurarcy is 0.502

# %% [markdown]
# # III. BAGGING-LOG MODEL

# %% [markdown]
# Notation on These functions:
# 1. extract_mat():
#
#   **TAKES IN** a list returned by a loadmat function.
#
#   **RETURN** an array that have all the points in the mat file.
#
# 2. get_f():
#
#   **TAKES IN** a direction that contains a _single_ .mat file.
#
#   **RETURN** an ndarray contains the pairwise euclidian distance between the coordinate contains in the .mat file.
#
# 3. feature_extraction():
#
#   **TAKES IN** a direction that contains the direction that contains _all_ the .mat file for the train.
#
#   **RETURNS** a ndarray contains the train_x with features set as pairwise euclidian distance between the coordinate contains in the .mat file.
#
# 4. f_pca():
#
#   **TAKES IN** a ndarray contains all the train_x.
#
#   **RETURNS** a ndarray contains decomposed x and the decompositon model.
#
# 5. BaggingLR_w_pca():
#
#   **TAKES IN** two ndarrays as train_x(without decomposition) and train_y.
#
#   **RETURNS** the Logistic-Bagging model trained with decomposed-train_x and train_y.
#
# 6. claim_possible_acc_BL():
#
#   **TAKES IN** three arguments which is the direction that contains _all_the .mat file for x, the direction that contains a file named *label.csv* that have a column named as emotion_idx as the train_y.
#
#   **RETURNS** the possible accuracy of the Logistic-Bagging model.

# %%
def extract_mat(x):
    v = list(x.keys())[-1]
    return x[v]

def get_f(file_dir):
    '''Argument: 
        file_dir: The whole direction contain the exact mat file
       
       Return:
        a np.array contains the featrues of single X'''
    a = extract_mat(loadmat(file_dir))
    b = cdist(a, a)
    r = b[np.triu_indices(b.shape[1], 1)].flatten()
    return r

def feature_extraction(dir_x):
    if (dir_x[-1] != '/'):
        dir_x = dir_x + '/'
    
    fea_start = time.time()
    
    filenames = list(os.listdir(dir_x))
    filenames.sort()
    X = np.array(list(map(get_f, ((dir_x + i) for i in filenames))))
    
    fea_end = time.time()
    fea_time = fea_end - fea_start
    
    print('Feature Extraction Completed!')
    print(f'Feature Extraction Cost: {fea_time: 0.2f} Seconds')
    return X

def f_pca(x):
    my_pca = PCA(n_components = 130)
    new_X = my_pca.fit_transform(x)
    compo = sum(my_pca.explained_variance_ratio_)*100
    print(f'The Decomposition take up {compo: 0.2f}% Information of original Data')
    
    return new_X, my_pca

def BaggingLR_w_pca(train_X, train_y):
    
    train_X, pca_mode = f_pca(train_X)    
    
    start_lr = time.time()
    lr = LogisticRegression(C = 1,
                            penalty = 'l2',
                            fit_intercept = False)
    Bag_lr = BaggingClassifier(lr,
                               n_estimators = 70,
                               n_jobs = 5,
                               bootstrap_features = True,
                               verbose = 7)
    Bag_lr.fit(train_X, train_y)
    end_lr = time.time()
    
    Train_time = end_lr - start_lr
    print(f'The Time for train is: {Train_time: 0.2f} Seconds')
    return Bag_lr, pca_mode


def claim_possible_acc_BL(X_path, y_path, n_iter = 1):
    X = feature_extraction(X_path)
    y = pd.read_csv(y_path).emotion_idx
    
    accs = []
    for i in range(n_iter):
        trainx, testx, trainy, testy = train_test_split(X, y, test_size = .2)
        model, pca_mode= BaggingLR_w_pca(trainx, trainy)
        new_testx = pca_mode.transform(testx)
        testy_hat = model.predict(new_testx)
        accs.append(accuracy_score(testy, testy_hat))
    return np.mean(accs)

# %%
claim_possible_acc_BL('train_set/points', 'train_set/label.csv')

# %% [markdown]
# reference: https://www.cnblogs.com/wj-1314/p/10422159.html
